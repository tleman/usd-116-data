# %%
import re, csv
import PyPDF2
import openpyxl

# %%
pdf_path = 'data/FY23-Tentative-Budget-Expenditures-resave.pdf'
output_file_type = 'csv'
# the relevant data starts on this line (each pdf page has a header)
data_start_line = 7

# %%
# read pdf file into list
raw_pages = []
with open(pdf_path, 'rb') as f:
    pdf = PyPDF2.PdfFileReader(f)
    for page in pdf.pages:
        raw_pages.append(page.extract_text())
    n_pages =  pdf.getNumPages()
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.

# %%
for page in pdf.pages[0:2]:
    page

# %%
n_pages
# Out:
# 122

# %%
clean_lines = []
for i, page in enumerate(raw_pages):
    this_page = page.splitlines(keepends=True)
    for line in this_page:
        clean_line = line.replace('\xa0', ' ')
        clean_line = clean_line.strip()
        clean_lines.append(clean_line)

# %%
clean_lines[0:30]
# Out:
# ['3frbud12.p 76-4 Urbana, IL 06/15/22 Page:1',
#  '05.22.02.00.00 TENTATIVE BUDGET-EXPENSES  (Date: 6/2022)  9:52 AM',
#  'Account Level 2022-23 2021-22 2021-22 2020-21 2020-21',
#  'FDTLOC FUNC OBJ  SJ',
#  'Description                           TENTATIVE   Original Budget     FYTD Activity   Original Budget     FYTD Activity',
#  '10',
#  'EDUCATION',
#  '000000',
#  'UNRESTRICTED',
#  '10E000 0000 0000 00 000000',
#  'SUMMARY ACCOUNT OFFSET',
#  '',
#  '',
#  '-40.00',
#  '',
#  '4.34',
#  '10E000 0000 1230 00 000000',
#  '',
#  '',
#  '245.00',
#  '',
#  '754.50',
#  '10E000 0000 1270 00 000000',
#  '',
#  '',
#  '220.00',
#  '',
#  '',
#  '10E000 0000 2160 00 000000',
#  '']

# %%
# PDF's may be given with different numbers of budget (dollar) columns
n_budget_cols = 5
# 5 account number columns + 1 account description + N budget columns
MAX_BUDGET_ENTRY_COLS = 5 + 1 + n_budget_cols

funds = {}
accounts = {}

# first line of new page = any chars + Urbana,IL + date + Page:# + end of line
new_page_pattern = '.*Urbana, IL \d\d/\d\d/\d\d Page:\d{1,3}$'

i = 0
while i < len(clean_lines):
    current_line = clean_lines[i]
    if re.match(new_page_pattern, current_line):
        i += 1
        print(f'HEADER: {current_line}')
    # line 2 of header = start of string + 10 digits separated by decimals
    elif re.match('^\d\d\.\d\d\.\d\d\.\d\d\.\d\d', current_line):
        i += 1
        print(f'HEADER: {current_line}')
    # line 3 of header = begins with "Account Level"
    elif re.match('^Account Level', current_line):
        i += 1
        print(f'HEADER: {current_line}')
    # line 4 of header = begins with "FDTLOC"
    elif re.match('^FDTLOC', current_line):
        i += 1
        print(f'HEADER: {current_line}')
    # line 5 of header = begins with "Description"
    elif re.match('^Description', current_line):
        i += 1
        print(f'HEADER: {current_line}')
    # fund number = start of string + two digit number + end of string
    elif re.match('^\d{2}$', current_line):
        # this line is the fund number, next line is the fund name
        funds[current_line] = clean_lines[i+1]
        i += 2
        print(f'FUND number:{current_line} name:{funds[current_line]}')
    # account number = start of string + six digit number + end of string
    elif re.match('^\d{6}$', current_line):
        # this line is the account number, next line is the account name
        accounts[current_line] = clean_lines[i+1]
        i += 2
        print(f'ACCOUNT number:{current_line} name:{accounts[current_line]}')
    # budget line item - ##E### ####
    elif re.match('^\d{2}E\d{3} \d{4}', current_line):
        # account numbers
        budget_line = current_line.split()
        # if the next line is empty or numeric, the account description is blank in the PDF
        if not clean_lines[i+1] or clean_lines[i+1].isnumeric():
            budget_line.append('BLANK')
        # continue adding budget line entries until we reach either
        #    1) the next budget line item
        #    2) the next page
        #    3) the maximum number of columns (helps with edge cases with subtotals)
        while not (re.match('^\d{2}E\d{3} \d{4}', clean_lines[i+1]) or 
                   re.match(new_page_pattern, clean_lines[i+1])):
            i += 1
            budget_line.append(clean_lines[i])
            if len(budget_line) == MAX_BUDGET_ENTRY_COLS:
                break
        i += 1
        print('ENTRY:', budget_line)
    else:
        i += 1
        print(f'SKIPPING: {current_line}')
# Out:
# SKIPPING:
# SKIPPING: 352.47
# SKIPPING:
# SKIPPING:
# HEADER: 3frbud12.p 76-4 Urbana, IL 06/15/22 Page:116
# HEADER: 05.22.02.00.00 TENTATIVE BUDGET-EXPENSES  (Date: 6/2022)  9:52 AM
# HEADER: Account Level 2022-23 2021-22 2021-22 2020-21 2020-21
# HEADER: FDTLOC FUNC OBJ  SJ
# HEADER: Description                           TENTATIVE   Original Budget     FYTD Activity   Original Budget     FYTD Activity
# FUND number:50 name:IMRF
# ACCOUNT number:780000 name:CCLC-2013
# ENTRY: ['50E000', '2620', '2130', '00', '784421', 'BLANK', '', '', '396.92', '', '']
# ENTRY: ['50E000', '2620', '2140', '00', '784421', 'BLANK', '', '', '136.20', '', '']
# ENTRY: ['50E003', '2900', '2140', '00', '784421', 'BLANK', '', '', '120.80', '', '']
# ENTRY: ['50E010', '2900', '2140', '00', '784421', 'BLANK', '', '', '72.53', '', '']
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING: _________________
# SKIPPING:
# SKIPPING:
# SKIPPING: 50 --- ---- ----    78----
# SKIPPING:
# SKIPPING:
# SKIPPING: 2,401.73
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING: =================
# SKIPPING:
# SKIPPING:
# ACCOUNT number:830000 name:YOUNG ACHIEVERS
# ENTRY: ['50E009', '1130', '2120', '00', '830000', 'MUNICIPAL RETIREMENT', '4,300', '4,300.00', '2,900.44', '4,300.00', '4,155.21']
# ENTRY: ['50E009', '1130', '2130', '00', '830000', 'FICA', '2,100', '2,100.00', '1,653.03', '2,100.00', '2,191.66']
# ENTRY: ['50E009', '1130', '2140', '00', '830000', 'MEDICARE ONLY', '', '', '386.54', '', '512.55']
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: 50 --- ---- ----    83----
# SKIPPING: 6,400
# SKIPPING: 6,400.00
# SKIPPING: 4,940.01
# SKIPPING: 6,400.00
# SKIPPING: 6,859.42
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# ACCOUNT number:870000 name:STAFF DEVELOPMENT
# ENTRY: ['50E000', '2210', '2120', '24', '870000', 'BLANK', '', '', '18.66', '', '13.18']
# ENTRY: ['50E000', '2210', '2130', '24', '870000', 'BLANK', '', '', '11.16', '', '6.80']
# ENTRY: ['50E000', '2210', '2140', '24', '870000', 'BLANK', '', '', '179.70', '', '118.08']
# ENTRY: ['50E000', '2216', '2140', '24', '870000', 'BLANK', '', '', '1,154.73', '', '1,006.41']
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING: _________________
# SKIPPING:
# SKIPPING: _________________
# SKIPPING: 50 --- ---- ----    87----
# SKIPPING:
# SKIPPING:
# SKIPPING: 1,364.25
# SKIPPING:
# SKIPPING: 1,144.47
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING: =================
# SKIPPING:
# SKIPPING: =================
# ACCOUNT number:880000 name:TITLE III
# ENTRY: ['50E000', '1800', '2120', '18', '884909', 'MUNICIPAL RETIREMENT', '', '', '376.02', '', '']
# ENTRY: ['50E000', '1800', '2130', '18', '884909', 'FICA', '', '', '225.02', '', '']
# ENTRY: ['50E000', '1800', '2140', '18', '884909', 'BLANK', '', '', '52.62', '', '']
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING: _________________
# SKIPPING:
# SKIPPING:
# SKIPPING: 50 --- ---- ----    88----
# SKIPPING:
# SKIPPING:
# SKIPPING: 653.66
# SKIPPING:
# SKIPPING:
# HEADER: 3frbud12.p 76-4 Urbana, IL 06/15/22 Page:117
# HEADER: 05.22.02.00.00 TENTATIVE BUDGET-EXPENSES  (Date: 6/2022)  9:52 AM
# HEADER: Account Level 2022-23 2021-22 2021-22 2020-21 2020-21
# HEADER: FDTLOC FUNC OBJ  SJ
# HEADER: Description                           TENTATIVE   Original Budget     FYTD Activity   Original Budget     FYTD Activity
# FUND number:50 name:IMRF
# ACCOUNT number:880000 name:TITLE III
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING: =================
# SKIPPING:
# SKIPPING:
# ACCOUNT number:910000 name:STUDENT MENTOR PROGRAM
# ENTRY: ['50E000', '2900', '2120', '24', '910000', 'STUDENT MENTOR COORD IMRF', '16,000', '16,000.00', '8,976.59', '3,000.00', '15,594.00']
# ENTRY: ['50E000', '2900', '2130', '24', '910000', 'STUDENT MENTOR COORD FICA', '10,000', '10,000.00', '5,443.19', '2,000.00', '9,149.21']
# ENTRY: ['50E000', '2900', '2140', '24', '910000', 'STUDENT MENTOR COORD MEDICARE', '1,369', '1,369.00', '1,660.35', '1,369.00', '2,141.21']
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: 50 --- ---- ----    91----
# SKIPPING: 27,369
# SKIPPING: 27,369.00
# SKIPPING: 16,080.13
# SKIPPING: 6,369.00
# SKIPPING: 26,884.42
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# ACCOUNT number:920000 name:TITLE II
# ENTRY: ['50E000', '2210', '2120', '24', '924932', 'BLANK', '', '', '20.56', '', '']
# ENTRY: ['50E000', '2210', '2130', '24', '924932', 'BLANK', '', '', '12.30', '', '']
# ENTRY: ['50E000', '2210', '2140', '24', '924932', 'BLANK', '', '', '53.72', '', '']
# ENTRY: ['50E000', '2640', '2120', '24', '924932', 'BLANK', '', '', '1,382.45', '', '']
# ENTRY: ['50E000', '2640', '2130', '24', '924932', 'BLANK', '', '', '842.85', '', '']
# ENTRY: ['50E000', '2640', '2140', '24', '924932', 'BLANK', '', '', '197.10', '', '']
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING: _________________
# SKIPPING:
# SKIPPING:
# SKIPPING: 50 --- ---- ----    92----
# SKIPPING:
# SKIPPING:
# SKIPPING: 2,508.98
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING: =================
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: 50 --- ---- ----    ------
# SKIPPING: 1,640,000
# SKIPPING: 1,519,532.00
# SKIPPING: 1,628,435.63
# SKIPPING: 1,594,600.00
# SKIPPING: 1,682,717.29
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# FUND number:60 name:WORKING CASH
# ACCOUNT number:160000 name:CCH
# ENTRY: ['60E000', '2535', '5300', '00', '167210', 'BUILDING IMPROVEMENTS-ALL', '57,080', '57,080.00', '', '65,923.00', '']
# ENTRY: ['60E009', '2535', '5300', '00', '167210', 'BUILDING IMPROVEMENTS-UHS', '', '', '54,219.00', '', '']
# ENTRY: ['60E000', '2547', '3100', '24', '167210', 'TECH INFRASTRUCTURE CONT. SRVC', '', '', '2,668.48', '', '8,850.00']
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# HEADER: 3frbud12.p 76-4 Urbana, IL 06/15/22 Page:118
# HEADER: 05.22.02.00.00 TENTATIVE BUDGET-EXPENSES  (Date: 6/2022)  9:52 AM
# HEADER: Account Level 2022-23 2021-22 2021-22 2020-21 2020-21
# HEADER: FDTLOC FUNC OBJ  SJ
# HEADER: Description                           TENTATIVE   Original Budget     FYTD Activity   Original Budget     FYTD Activity
# FUND number:60 name:WORKING CASH
# ACCOUNT number:160000 name:CCH
# SKIPPING: 60 --- ---- ----    16----
# SKIPPING: 57,080
# SKIPPING: 57,080.00
# SKIPPING: 56,887.48
# SKIPPING: 65,923.00
# SKIPPING: 8,850.00
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# ACCOUNT number:190000 name:Test Proctoring
# ENTRY: ['60E000', '2535', '5300', '00', '197210', 'BUILDING IMPROVEMENTS-ALL', '', '', '18,573.71', '709,135.00', '20,149.00']
# ENTRY: ['60E001', '2535', '5300', '00', '197210', 'BUILDING IMPROVEMENTS-LEAL', '275,000', '275,000.00', '323,666.34', '620,000.00', '176,809.87']
# ENTRY: ['60E003', '2535', '5300', '00', '197210', 'BUILDING IMPROVEMENTS-WILLIAMS', '5,000', '5,000.00', '', '', '12,675.00']
# ENTRY: ['60E004', '2535', '5300', '00', '197210', 'BUILDING IMPROVEMENTS-WILEY', '', '', '', '', '5,973.00']
# ENTRY: ['60E007', '2535', '5300', '00', '197210', 'BUILDING IMPROVEMENTS-YR', '4,320', '4,320.00', '4,320.00', '', '2,750.00']
# ENTRY: ['60E008', '2535', '5300', '00', '197210', 'BUILDING IMPROVEMENTS-UMS', '105,000', '105,000.00', '3,760.00', '62,530.00', '63,016.00']
# ENTRY: ['60E009', '2535', '5300', '00', '197210', 'BUILDING IMPROVEMENTS-UHS', '48,000', '48,000.00', '198,286.58', '119,100.00', '106,058.50']
# ENTRY: ['60E010', '2535', '5300', '00', '197210', 'BUILDING IMPROVEMENTS-KING', '25,000', '25,000.00', '70,624.36', '200,000.00', '169,924.83']
# ENTRY: ['60E011', '2535', '5300', '00', '197210', 'BUILDING IMPROVEMENTS-TP', '', '', '', '10,000.00', '5,750.00']
# ENTRY: ['60E013', '2535', '5300', '00', '197210', 'BUILDING IMPROVEMENTS-MAINT', '', '', '107,330.00', '95,000.00', '77,576.00']
# ENTRY: ['60E033', '2535', '5300', '00', '197210', 'BUILDING IMPROVEMENTS-UIAC', '102,758', '102,758.00', '119,540.00', '141,000.00', '24,910.92']
# ENTRY: ['60E000', '2547', '3100', '24', '197210', 'TECH INFRASTRUCTURE CONT. SRVC', '', '', '19,675.34', '', '72,487.31']
# ENTRY: ['60E000', '2547', '5400', '24', '197210', 'TECH INFRASTRUCTURE HARDWARE', '267,194', '267,194.00', '18,560.00', '', '']
# ENTRY: ['60E000', '2547', '5410', '24', '197210', 'TECH INFRASTRUCTURE E-RATABLE', '', '', '', '', '385,786.70']
# ENTRY: ['60E000', '5900', '3190', '00', '197210', 'BOND ISSUANCE COSTS', '', '', '768.00', '', '768.00']
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: 60 --- ---- ----    19----
# SKIPPING: 832,272
# SKIPPING: 832,272.00
# SKIPPING: 885,104.33
# SKIPPING: 1,956,765.00
# SKIPPING: 1,124,635.13
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# ACCOUNT number:210000 name:Carle CNA Partnership
# ENTRY: ['60E019', '2530', '3250', '00', '217210', 'RENT OF OFFICES-MTD', '191,080', '191,080.00', '175,156.63', '', '']
# ENTRY: ['60E000', '2535', '5300', '00', '217210', 'BUILDING IMPROVEMENTS-ALL', '80,000', '80,000.00', '15,000.00', '', '']
# ENTRY: ['60E001', '2535', '5300', '00', '217210', 'BUILDING IMPROVEMENTS-LEAL', '', '', '2,475.00', '', '']
# ENTRY: ['60E003', '2535', '5300', '00', '217210', 'BUILDING IMPROVEMENTS-WILLIAMS', '', '', '17,190.00', '', '']
# ENTRY: ['60E004', '2535', '5300', '00', '217210', 'BUILDING IMPROVEMENTS-WILEY', '', '', '6,100.00', '', '']
# ENTRY: ['60E007', '2535', '5300', '00', '217210', 'BUILDING IMPROVEMENTS-YR', '', '', '2,750.00', '', '']
# ENTRY: ['60E008', '2535', '5300', '00', '217210', 'BUILDING IMPROVEMENTS-UMS', '', '', '6,475.00', '', '']
# ENTRY: ['60E009', '2535', '5300', '00', '217210', 'BUILDING IMPROVEMENTS-UHS', '', '', '32,968.12', '', '']
# ENTRY: ['60E010', '2535', '5300', '00', '217210', 'BUILDING IMPROVEMENTS-KING', '', '', '27,643.00', '', '']
# HEADER: 3frbud12.p 76-4 Urbana, IL 06/15/22 Page:119
# HEADER: 05.22.02.00.00 TENTATIVE BUDGET-EXPENSES  (Date: 6/2022)  9:52 AM
# HEADER: Account Level 2022-23 2021-22 2021-22 2020-21 2020-21
# HEADER: FDTLOC FUNC OBJ  SJ
# HEADER: Description                           TENTATIVE   Original Budget     FYTD Activity   Original Budget     FYTD Activity
# FUND number:60 name:WORKING CASH
# ACCOUNT number:210000 name:Carle CNA Partnership
# ENTRY: ['60E011', '2535', '5300', '00', '217210', 'BUILDING IMPROVEMENTS-TP', '', '', '7,525.00', '', '']
# ENTRY: ['60E013', '2535', '5300', '00', '217210', 'BUILDING IMPROVEMENTS-MAINT', '', '', '43,314.23', '', '']
# ENTRY: ['60E019', '2535', '5300', '00', '217210', 'BUILDING IMPROVEMENTS-CO', '42,000', '42,000.00', '44,100.00', '', '']
# ENTRY: ['60E033', '2535', '5300', '00', '217210', 'BUILDING IMPROVEMENTS-UIAC', '', '', '10,750.00', '', '']
# ENTRY: ['60E019', '2542', '4100', '00', '217210', 'CENTRAL OFFICE MOVE TO MTD', '40,000', '40,000.00', '60,313.32', '', '']
# ENTRY: ['60E000', '2547', '4000', '00', '217210', 'TECH SUPPLIES-100% ECF', '181,049', '181,049.00', '165,619.99', '', '']
# ENTRY: ['60E000', '2547', '4100', '24', '217210', 'TECH INFRASTRUCTURE SUPPLIES', '', '', '1,548.00', '', '']
# ENTRY: ['60E000', '2547', '5400', '24', '217210', 'TECH INFRASTRUCTURE HARDWARE', '1,000,000', '1,000,000.00', '562,740.80', '', '']
# ENTRY: ['60E000', '2547', '5410', '24', '217210', 'TECH INFRASTRUCTURE E-RATABLE', '', '', '24,876.21', '', '']
# ENTRY: ['60E000', '5900', '3190', '00', '217210', 'BOND ISSUANCE COSTS', '', '', '', '', '52,971.67']
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING:
# SKIPPING: _________________
# SKIPPING: 60 --- ---- ----    21----
# SKIPPING: 1,534,129
# SKIPPING: 1,534,129.00
# SKIPPING: 1,206,545.30
# SKIPPING:
# SKIPPING: 52,971.67
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING:
# SKIPPING: =================
# ACCOUNT number:550000 name:THOMAS PAINE BUILDING BUDGET
# ENTRY: ['60E011', '2535', '3180', '00', '557210', 'TP ARCHITECT/ENG FEES', '', '', '674,832.70', '', '161,694.12']
# ENTRY: ['60E011', '2535', '5300', '00', '557210', 'CONSTRUCTION-TP 2021 BONDS', '8,002,119', '8,002,119.00', '122,610.15', '', '']
# ENTRY: ['60E011', '2535', '5302', '00', '557210', 'CONSTRUCTION-TP OWNERS COSTS', '', '', '38,902.36', '', '']
# ENTRY: ['60E011', '5900', '3190', '00', '557210', 'BLANK', '', '', '', '', '144,353.28']
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING:
# SKIPPING: _________________
# SKIPPING: 60 --- ---- ----    55----
# SKIPPING: 8,002,119
# SKIPPING: 8,002,119.00
# SKIPPING: 836,345.21
# SKIPPING:
# SKIPPING: 306,047.40
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING:
# SKIPPING: =================
# ACCOUNT number:570000 name:YANKEE RIDGE BUILDING BUDGET
# ENTRY: ['60E007', '2535', '5300', '00', '577210', 'CONSTRUCTION-YR/2017 BONDS', '20,000', '20,000.00', '25,677.92', '', '']
# ENTRY: ['60E011', '2535', '5300', '00', '577210', 'TP CONSTRUCTION-2017 BONDS', '', '', '977,010.45', '', '']
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING:
# SKIPPING:
# SKIPPING: 60 --- ---- ----    57----
# SKIPPING: 20,000
# SKIPPING: 20,000.00
# SKIPPING: 1,002,688.37
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: 60 --- ---- ----    ------
# SKIPPING: 10,445,600
# SKIPPING: 10,445,600.00
# SKIPPING: 3,987,570.69
# SKIPPING: 2,022,688.00
# SKIPPING: 1,492,504.20
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# HEADER: 3frbud12.p 76-4 Urbana, IL 06/15/22 Page:120
# HEADER: 05.22.02.00.00 TENTATIVE BUDGET-EXPENSES  (Date: 6/2022)  9:52 AM
# HEADER: Account Level 2022-23 2021-22 2021-22 2020-21 2020-21
# HEADER: FDTLOC FUNC OBJ  SJ
# HEADER: Description                           TENTATIVE   Original Budget     FYTD Activity   Original Budget     FYTD Activity
# FUND number:65 name:FACILITY SALES TAX
# ACCOUNT number:000000 name:UNRESTRICTED
# ENTRY: ['65E000', '8600', '6600', '00', '000000', 'TRANSFER TO DEBT SERVICE 2010', '1,465,000', '1,390,000.00', '1,390,000.00', '1,300,000.00', '1,300,000.00']
# ENTRY: ['65E000', '8700', '6600', '00', '000000', 'TRANSFER TO DEBT SERVICE 2010', '111,989', '139,706.00', '19,218.33', '176,410.00', '166,371.84']
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: 65 --- ---- ----    00----
# SKIPPING: 1,576,989
# SKIPPING: 1,529,706.00
# SKIPPING: 1,409,218.33
# SKIPPING: 1,476,410.00
# SKIPPING: 1,466,371.84
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# ACCOUNT number:550000 name:THOMAS PAINE BUILDING BUDGET
# ENTRY: ['65E011', '2535', '3180', '00', '550000', 'TP ARCHITECT/ENG FEES', '', '', '', '50,000.00', '38,010.00']
# ENTRY: ['65E011', '2535', '5300', '00', '550000', 'TP RENOVATION', '7,000,000', '', '', '', '']
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING:
# SKIPPING:
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: 65 --- ---- ----    55----
# SKIPPING: 7,000,000
# SKIPPING:
# SKIPPING:
# SKIPPING: 50,000.00
# SKIPPING: 38,010.00
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING:
# SKIPPING:
# SKIPPING: =================
# SKIPPING: =================
# ACCOUNT number:560000 name:UECS BUILDING BUDGET
# ENTRY: ['65E006', '8600', '6600', '00', '560000', "TRANSFER DEBT SERVICE '11PRIN", '436,000', '397,000.00', '397,000.00', '385,000.00', '385,000.00']
# ENTRY: ['65E006', '8700', '6600', '00', '560000', "TRANSFER DEBT SERVICE '11 INT", '20,004', '27,065.00', '15,991.49', '98,319.00', '98,318.75']
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: 65 --- ---- ----    56----
# SKIPPING: 456,004
# SKIPPING: 424,065.00
# SKIPPING: 412,991.49
# SKIPPING: 483,319.00
# SKIPPING: 483,318.75
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: 65 --- ---- ----    ------
# SKIPPING: 9,032,993
# SKIPPING: 1,953,771.00
# SKIPPING: 1,822,209.82
# SKIPPING: 2,009,729.00
# SKIPPING: 1,987,700.59
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# FUND number:70 name:WORKING CASH
# ACCOUNT number:000000 name:UNRESTRICTED
# ENTRY: ['70E000', '8120', '7020', '00', '000000', 'PERMANENT TRANS INTEREST EDUCA', '1,000', '1,000.00', '', '1,000.00', '179.56']
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING: _________________
# SKIPPING:
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: 70 --- ---- ----    00----
# SKIPPING: 1,000
# SKIPPING: 1,000.00
# SKIPPING:
# SKIPPING: 1,000.00
# SKIPPING: 179.56
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING: =================
# SKIPPING:
# SKIPPING: =================
# SKIPPING: =================
# HEADER: 3frbud12.p 76-4 Urbana, IL 06/15/22 Page:121
# HEADER: 05.22.02.00.00 TENTATIVE BUDGET-EXPENSES  (Date: 6/2022)  9:52 AM
# HEADER: Account Level 2022-23 2021-22 2021-22 2020-21 2020-21
# HEADER: FDTLOC FUNC OBJ  SJ
# HEADER: Description                           TENTATIVE   Original Budget     FYTD Activity   Original Budget     FYTD Activity
# FUND number:70 name:WORKING CASH
# ACCOUNT number:000000 name:UNRESTRICTED
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING: _________________
# SKIPPING:
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: 70 --- ---- ----    ------
# SKIPPING: 1,000
# SKIPPING: 1,000.00
# SKIPPING:
# SKIPPING: 1,000.00
# SKIPPING: 179.56
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING: =================
# SKIPPING:
# SKIPPING: =================
# SKIPPING: =================
# FUND number:80 name:TORT
# ACCOUNT number:000000 name:UNRESTRICTED
# ENTRY: ['80E000', '2364', '5900', '00', '000000', 'PROPERTY LOSS DEDUCTIBLE', '100,000', '100,000.00', '41,049.28', '25,000.00', '-28,291.40']
# ENTRY: ['80E000', '2366', '6500', '00', '000000', 'INSURANCE SETTLEMENTS', '', '', '', '', '33,333.34']
# ENTRY: ['80E000', '2367', '3100', '00', '000000', 'CRIM HISTORY/FINGERPRINTING', '25,000', '25,000.00', '23,612.25', '25,000.00', '10,868.00']
# ENTRY: ['80E000', '2367', '3120', '00', '000000', 'AED TRAINING/SAFETY CONTR', '4,000', '4,000.00', '', '4,000.00', '10,352.41']
# ENTRY: ['80E000', '2367', '5400', '00', '000000', 'ADA/SAFETY EQUIPMENT', '2,000', '2,000.00', '3,383.97', '2,000.00', '366.42']
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: 80 --- ---- ----    00----
# SKIPPING: 131,000
# SKIPPING: 131,000.00
# SKIPPING: 68,045.50
# SKIPPING: 56,000.00
# SKIPPING: 26,628.77
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# ACCOUNT number:010000 name:Federal Basic Adult Education
# ENTRY: ['80E000', '2363', '3850', '00', '010000', 'UNEMPLOYMENT', '50,000', '50,000.00', '42,227.18', '50,000.00', '62,093.64']
# ENTRY: ['80E000', '2363', '3880', '00', '010000', 'UNEMPLOYMENT PROGRAM CONTRIBUT', '', '', '-8,150.00', '', '-11,111.00']
# ENTRY: ['80E000', '2364', '3830', '00', '010000', 'INSURANCE', '593,275', '593,275.00', '594,438.26', '190,000.00', '169,085.81']
# ENTRY: ['80E000', '2369', '3180', '00', '010000', 'ATTORNEY FEES', '125,000', '125,000.00', '107,432.73', '225,000.00', '107,068.58']
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: 80 --- ---- ----    01----
# SKIPPING: 768,275
# SKIPPING: 768,275.00
# SKIPPING: 735,948.17
# SKIPPING: 465,000.00
# SKIPPING: 327,137.03
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# ACCOUNT number:020000 name:SELF-INSURED WC
# ENTRY: ['80E000', '2364', '3810', '00', '020000', 'WORK COMP EXCESS', '98,658', '98,658.00', '101,847.00', '73,873.00', '73,872.00']
# ENTRY: ['80E000', '2364', '3860', '00', '020000', 'CCMSI LOSS FUND', '150,000', '150,000.00', '214,121.18', '150,000.00', '269,008.92']
# ENTRY: ['80E000', '2364', '3880', '00', '020000', 'WORKERS COMP CONTRIBUTIONS', '', '', '-62,248.86', '', '-62,340.58']
# ENTRY: ['80E000', '2365', '3820', '00', '020000', 'WORK COMP TPA FEES', '27,000', '27,000.00', '27,000.00', '33,220.00', '27,000.00']
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: 80 --- ---- ----    02----
# SKIPPING: 275,658
# SKIPPING: 275,658.00
# SKIPPING: 280,719.32
# SKIPPING: 257,093.00
# SKIPPING: 307,540.34
# HEADER: 3frbud12.p 76-4 Urbana, IL 06/15/22 Page:122
# HEADER: 05.22.02.00.00 TENTATIVE BUDGET-EXPENSES  (Date: 6/2022)  9:52 AM
# HEADER: Account Level 2022-23 2021-22 2021-22 2020-21 2020-21
# HEADER: FDTLOC FUNC OBJ  SJ
# HEADER: Description                           TENTATIVE   Original Budget     FYTD Activity   Original Budget     FYTD Activity
# FUND number:80 name:TORT
# ACCOUNT number:020000 name:SELF-INSURED WC
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: 80 --- ---- ----    ------
# SKIPPING: 1,174,933
# SKIPPING: 1,174,933.00
# SKIPPING: 1,084,712.99
# SKIPPING: 778,093.00
# SKIPPING: 661,306.14
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# FUND number:90 name:L/S LEVY
# ACCOUNT number:000000 name:UNRESTRICTED
# ENTRY: ['90E008', '2542', '5202', '00', '000000', 'UMS 2020 L/S AMEND #21', '', '', '', '112,000.00', '113,014.48']
# ENTRY: ['90E004', '2542', '5203', '00', '000000', 'WILEY 2020 L/S AMEND #23', '', '', '2,593.00', '35,000.00', '31,772.23']
# ENTRY: ['90E008', '2542', '5203', '00', '000000', 'UMS 2022 L/S AMEND #22 & #23', '', '', '9,552.97', '', '']
# ENTRY: ['90E011', '2542', '5209', '00', '000000', 'TP 2021 L/S AMEND #16', '515,000', '515,000.00', '1,980.00', '', '']
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: 90 --- ---- ----    00----
# SKIPPING: 515,000
# SKIPPING: 515,000.00
# SKIPPING: 14,125.97
# SKIPPING: 147,000.00
# SKIPPING: 144,786.71
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING:
# SKIPPING:
# SKIPPING: ________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: _________________
# SKIPPING: 90 --- ---- ----    ------
# SKIPPING: 515,000
# SKIPPING: 515,000.00
# SKIPPING: 14,125.97
# SKIPPING: 147,000.00
# SKIPPING: 144,786.71
# SKIPPING:
# SKIPPING:
# SKIPPING: ================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: =================
# SKIPPING: __________________________________________________________________________________________________________________________________________________________________________
# SKIPPING: Grand Expense Totals
# SKIPPING: 109,418,226    100,013,810.00     69,647,251.63     78,560,751.00     72,264,808.53
# SKIPPING: Number of Accounts:
# SKIPPING: 3450
# SKIPPING: ************************ End of report ************************

# %%
len(clean_lines)
# Out:
# 28229

# %%
clean_lines[28150:28228]
# Out:
# ['=================',
#  '90',
#  'L/S LEVY',
#  '000000',
#  'UNRESTRICTED',
#  '90E008 2542 5202 00 000000',
#  'UMS 2020 L/S AMEND #21',
#  '',
#  '',
#  '',
#  '112,000.00',
#  '113,014.48',
#  '90E004 2542 5203 00 000000',
#  'WILEY 2020 L/S AMEND #23',
#  '',
#  '',
#  '2,593.00',
#  '35,000.00',
#  '31,772.23',
#  '90E008 2542 5203 00 000000',
#  'UMS 2022 L/S AMEND #22 & #23',
#  '',
#  '',
#  '9,552.97',
#  '',
#  '',
#  '90E011 2542 5209 00 000000',
#  'TP 2021 L/S AMEND #16',
#  '515,000',
#  '515,000.00',
#  '1,980.00',
#  '',
#  '',
#  '',
#  '',
#  '________________',
#  '_________________',
#  '_________________',
#  '_________________',
#  '_________________',
#  '90 --- ---- ----    00----',
#  '515,000',
#  '515,000.00',
#  '14,125.97',
#  '147,000.00',
#  '144,786.71',
#  '',
#  '',
#  '================',
#  '=================',
#  '=================',
#  '=================',
#  '=================',
#  '',
#  '',
#  '________________',
#  '_________________',
#  '_________________',
#  '_________________',
#  '_________________',
#  '90 --- ---- ----    ------',
#  '515,000',
#  '515,000.00',
#  '14,125.97',
#  '147,000.00',
#  '144,786.71',
#  '',
#  '',
#  '================',
#  '=================',
#  '=================',
#  '=================',
#  '=================',
#  '__________________________________________________________________________________________________________________________________________________________________________',
#  'Grand Expense Totals',
#  '109,418,226    100,013,810.00     69,647,251.63     78,560,751.00     72,264,808.53',
#  'Number of Accounts:',
#  '3450']
